# %% [markdown]
# # Question 1

# %%
listOne = [3, 6, 9, 12, 15, 18, 21]
listTwo = [4, 8, 12, 16, 20, 24, 28]
print(listOne[1::2]+listTwo[0::2])

# %% [markdown]
# # Question 2

# %%
Set1 = (10, 30, 40 , 60, 45)
Set2 = (20, 50, 10 , 40, 55)
List = list()
a = list(Set1)
b = list(Set2)
for c in Set1:
    for d in Set2:
        if d == c:
            a.remove(d)
        else:
            continue
Outcome = tuple(a)
print(Outcome)
# Out:
# (30, 60, 45)

# %% [markdown]
# # Question 3

# %%
numbers = input("Enter your numbers. Seperate them with commas:\n")
#Changing the string to a list of integers
list1 = numbers.split(",")
for loop in (list1):
    list1[list1.index(loop)] = int(loop)
print(list1)
a = list1[4]
list1.remove(a)
list1.insert(2,a)
list1.append(a)
print(list1)
# Out:
# Enter your numbers. Seperate them with commas:
# 12,11,12,13,15,64
# [12, 11, 12, 13, 15, 64]
# [12, 11, 15, 12, 13, 64, 15]

# %% [markdown]
# # Question 5

# %%
a = [1, 2, 3, 4, 5, 6, 7, 8, 9]

b = a[0:3]
c = a[3:6]
d = a[6:9]
b.reverse()
c.reverse()
d.reverse()
print(b,c,d)
# Out:
# [3, 2, 1] [6, 5, 4] [9, 8, 7]

# %% [markdown]
# # Question 6

# %%
list2 =[10, 20, 30, 10, 20, 40, 50]
dict1 ={}
for a in list2:
    dict1[a] = dict1.get(a,0) + 1
print(dict1)
# Out:
# {10: 2, 20: 2, 30: 1, 40: 1, 50: 1}

# %% [markdown]
# # Question 7

# %%
rollNumber = [47,64,69,37,76,83,95,97]
Dict ={'Jhon':47, 'Emma':69, 'Kelly':76, 'Jason':97}
remove = list()
for a in rollNumber:
    if a not in list(Dict.values()):
        remove.append(a)
for b in range(len(remove)):
    rollNumber.remove(remove[b])
print(rollNumber)
# Out:
# [47, 69, 76, 97]

# %% [markdown]
# # Question 8

# %%
list3 = [87, 45, 41, 65, 94, 41, 99, 94]
list4 = list3
for a in list4:
    x = list4.count(a)
    if x>1:
        list3.remove(a)
print(list3)
print(tuple(list3))
print(min(list3))
print(max(list3))
# Out:
# [87, 45, 65, 41, 99, 94]
# (87, 45, 65, 41, 99, 94)
# 41
# 99

# %% [markdown]
# # Question 9

# %%
word ="pynativepynvepynative"
letters = list(word)
count = dict()
for a in letters:
    count[a] = count.get(a,0) + 1
print(count)
# Out:
# {'p': 3, 'y': 3, 'n': 3, 'a': 2, 't': 2, 'i': 2, 'v': 3, 'e': 3}

# %% [markdown]
# # Question 10

# %%
char = "P@#yn26at^&i5ve"
print("Characters: ",len(char))
sep = list(char)
Numbers = 0
Lowercase = 0
Uppercase = 0
Symbols = 0
print(sep)
for a in sep:
    if a.isnumeric():
        Numbers = Numbers + 1
    elif a.islower():
        Lowercase = Lowercase + 1
    elif a.isupper():
        Uppercase = Uppercase + 1
    else:
        Symbols = Symbols + 1
print("Uppercase letters, ",Uppercase)
print("Lowercase letters, ",Lowercase)
print("Numbers: ",Numbers)
print("Symbols: ",Symbols)
# Out:
# Characters:  15
# ['P', '@', '#', 'y', 'n', '2', '6', 'a', 't', '^', '&', 'i', '5', 'v', 'e']
# Uppercase letters,  1
# Lowercase letters,  7
# Numbers:  3
# Symbols:  4

# %% [markdown]
# # Question 11

# %%
name = input("Enter your name:")

if len(name)%2 ==0 and len(name)<=7:
    print("Enter an odd numbered name! And of a length greater than 7")
else:
    n = 7
    n1 = len(name)
    m = (2 + (n1-n)/2)
    m1 = m+3
    outcome = name[int(m):int(m1)]
    print(outcome)
# Out:
# Enter your name:hgjs
# Enter an odd numbered name! And of a length greater than 7
