# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv')
df2 = pd.read_csv('df2.csv')
df3 = pd.read_csv('df3.csv')

# %% [markdown]
# # Area Plot

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.7)

# %% [markdown]
# # Line Plot

# %%
df2.plot.line()

# %%
df2.plot.line(figsize=(12,5))

# %% [markdown]
# # Bar Plots

# %%
df2.plot.bar()

# %%
df2.plot.bar(figsize=(12,5))

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.bar(figsize=(12,5),stacked=True)

# %% [markdown]
# # Histograms

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(bins = 100,figsize=(12,5))

# %% [markdown]
# # Scatter plots

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*70)
# Out:
# C:\Users\zalego\Anaconda3\lib\site-packages\matplotlib\collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# # Box Plots

# %%
df2.plot.box()

# %%
df2.plot.box(by='a')

# %% [markdown]
# # Hexbin Plots

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %% [markdown]
# # Kde(Kernel Density Estimation) Plots

# %%
df2.plot.kde()

# %%
df2['a'].plot.kde()

# %% [markdown]
# # Horizontal Bar Plot

# %%
df2.plot.barh(figsize=(10,10))
