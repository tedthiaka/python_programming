# %%
import pandas as pd
df = pd.read_csv("Ongoza data.csv")
df.head()
# Out:
#    application_year  selected  showup  finished info_venture_country  \
# 0              2016       1.0     1.0       1.0               Rwanda
# 1              2015       NaN     NaN       0.0                Kenya
# 2              2014       NaN     NaN       0.0                India
# 3              2016       0.0     NaN       NaN               Mexico
# 4              2016       0.0     0.0       0.0               Rwanda
#
#   info_venture_country_hq             venture region  info_has_website  \
# 0                  Rwanda         Sub-Saharan Africa                 1
# 1                   Kenya         Sub-Saharan Africa                 1
# 2                   India                 South Asia                 1
# 3                  Mexico  Latin America & Caribbean                 0
# 4                  Rwanda         Sub-Saharan Africa                 0
#
#    info_founding_year   info_legal_status  ... found_name3_gender  \
# ...
